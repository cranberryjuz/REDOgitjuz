# %% [markdown]
# ## 01 L40
# Author: **Handsome Koh** <br>
# Date: *03/10/2025* <br>

# %%
print("handsome koh")
# Out:
# handsome koh

# %%
a = 4896
b = 1314

c = a/b
c
# Out:
# 3.7260273972602738

# %%
print("{:.2f}".format(c))
# Out:
# 3.73
