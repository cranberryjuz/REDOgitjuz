# %% [markdown]
# # Data Types
#
# ### Float & Integer

# %%
a = 13.14
b = 4896
print("a = ", a,"is", type(a))
print("b = ", b,"is", type(b))
# Out:
# a =  13.14 is <class 'float'>
# b =  4896 is <class 'int'>

# %% [markdown]
# ## String

# %%
sentence_str = "cranberryjuz is nice"
sentence_lst = sentence_str.split()
print(sentence_str)
print(sentence_lst)
# Out:
# cranberryjuz is nice
# ['cranberryjuz', 'is', 'nice']

# %% [markdown]
# ### Boolean

# %%
num1 = 4896
num2 = 0
num3 = -1

print(bool(num1), bool(num2), bool(num3))
# Out:
# True False True

# %% [markdown]
# ### Data Structures in Python
# ##### tupple is more efficient but restricted. List is leff efficeint but flexible

# %%
weekdays_tup = ('Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday')
weekdays_tup
# Out:
# ('Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday')

# %%
str1 = "Cranberry"
str2 = "Juz"
str3 = 13.14
str4 = 4896
str5 = True

record_lst = list()
record_lst.append(str1)
record_lst.append(str2)
record_lst.append(str3)
record_lst.append(str4)
record_lst.append(str5)
record_lst
# Out:
# ['Cranberry', 'Juz', 13.14, 4896, True]

# %% [markdown]
# ### Dictionary

# %%
record_dict = dict()
record_dict['first'] = str1
record_dict['last'] = str2
record_dict['rating'] = str3
record_dict['salary'] = str4
record_dict['executive'] = str5
record_dict
# Out:
# {'first': 'Cranberry',
#  'last': 'Juz',
#  'rating': 13.14,
#  'salary': 4896,
#  'executive': True}

# %% [markdown]
# ## NumPy
#
# Numpy random number generator
# it all started from a random number but its not really a random number either. if use the same seed, it will alwasy start from the same number

# %%
import numpy as np

# %%
np.random.seed(10)

# %%
rand_arr = np.random.random((2,2)) ## array with random values
print(np.round(rand_arr,3))
# Out:
# [[0.004 0.512]
#  [0.813 0.613]]

# %% [markdown]
# ### Dealing with File
#
# Import plain text file
# oopen file in python has 3 modes:
# 1. r - read only
# 2. w - write / overwrite
# 3. a - append / write at the bottom

# %%
 --generate-config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 --generate-config
#
# NameError: name 'generate' is not defined

# %%
sentence_file = open('Sentence.txt','r')
sentence_file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sentence_file = open('Sentence.txt','r')
#       2 sentence_file
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Sentence.txt'

# %%
Import pandas as pd
# Out:
#   Cell In[34], line 1
#     Import pandas as pd
#            ^
# SyntaxError: invalid syntax

# %%
df=[d.read_csv('titanis.csv')
